# %% [markdown]
# # Assignment 02
# ## Name: Matt Briskey

# %%
# load the data
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/frankData612/data_612/master/stock_data/stocks_yahoo.csv', low_memory=False)
df
# Out:
#           no         date                                       company_name  \
# 0          1  Nov 21 2019                               GOOG - Alphabet Inc.
# 1          2  Nov 21 2019                              GOOGL - Alphabet Inc.
# 2          3  Nov 21 2019  IBM - International Business Machines Corporation
# 3          4  Nov 21 2019                       MSFT - Microsoft Corporation
# 4          5  Nov 21 2019                                  AAPL - Apple Inc.
# ...      ...          ...                                                ...
# 67900  67901  Apr 28 2020                                   FLEX - Flex Ltd.
# 67901  67902  Apr 28 2020                    MEI - Methode Electronics, Inc.
# 67902  67903  Apr 28 2020                        IEC - IEC Electronics Corp.
# 67903  67904  Apr 28 2020                       MGLN - Magellan Health, Inc.
# 67904  67905  Apr 28 2020                                 ZS - Zscaler, Inc.
#
# ...

# %%
# Show the type

print(df.dtypes)
# Out:
# no                     int64
# date                  object
# company_name          object
# price_at_close       float64
# price_change          object
# price_after_hours    float64
# previous_close       float64
# today opened         float64
# price range           object
# 52 week range         object
# volume                object
# average volume       float64
# market cap            object
# beta (3Y Monthly)    float64
# PE Ratio             float64
# EPS                  float64
# earnings date         object
# Dividend Yield        object
# 1Y target est        float64
# dtype: object

# %%
# convert the 'date' column to datetime format

df['date']= pd.to_datetime(df['date'])

# %%
# Show the type, date columnn should be converted to  datetime type instead of object

df.dtypes
# Out:
# no                            int64
# date                 datetime64[ns]
# company_name                 object
# price_at_close              float64
# price_change                 object
# price_after_hours           float64
# previous_close              float64
# today opened                float64
# price range                  object
# 52 week range                object
# volume                       object
# average volume              float64
# market cap                   object
# beta (3Y Monthly)           float64
# PE Ratio                    float64
# EPS                         float64
# earnings date                object
# Dividend Yield               object
# 1Y target est               float64
# dtype: object

# %%
# Show the .head()

df.head(n=6)
# Out:
#    no       date                                       company_name  \
# 0   1 2019-11-21                               GOOG - Alphabet Inc.
# 1   2 2019-11-21                              GOOGL - Alphabet Inc.
# 2   3 2019-11-21  IBM - International Business Machines Corporation
# 3   4 2019-11-21                       MSFT - Microsoft Corporation
# 4   5 2019-11-21                                  AAPL - Apple Inc.
# 5   6 2019-11-21                            AMZN - Amazon.com, Inc.
#
#    price_at_close     price_change  price_after_hours  previous_close  \
# 0         1301.35   -1.70 (-0.13%)            1301.35         1303.05
# 1         1300.14   -1.72 (-0.13%)            1300.14         1301.86
# 2          133.84   +0.64 (+0.48%)             133.84          133.20
# 3          149.48   -0.14 (-0.09%)             149.48          149.62
# 4          262.01   -1.18 (-0.45%)             262.01          263.19
# ...

# %%
# Show the .tail()

df.tail(n=6)
# Out:
#           no       date                     company_name  price_at_close  \
# 67899  67900 2020-04-28              PLXS - Plexus Corp.           62.36
# 67900  67901 2020-04-28                 FLEX - Flex Ltd.            9.11
# 67901  67902 2020-04-28  MEI - Methode Electronics, Inc.           29.84
# 67902  67903 2020-04-28      IEC - IEC Electronics Corp.            7.01
# 67903  67904 2020-04-28     MGLN - Magellan Health, Inc.           55.11
# 67904  67905 2020-04-28               ZS - Zscaler, Inc.           66.72
#
#          price_change  price_after_hours  previous_close  today opened  \
# 67899  +1.80 (+2.97%)              62.36           60.56         61.77
# 67900  +0.30 (+3.41%)               9.11            8.81          9.11
# 67901  +0.32 (+1.08%)              29.84           29.52         30.19
# 67902    0.00 (0.00%)               7.01            7.01          7.10
# 67903  -0.03 (-0.05%)              55.11           55.14         54.74
# ...

# %%
# get column names

print(df.columns)
# Out:
# Index(['no', 'date', 'company_name', 'price_at_close', 'price_change',
#        'price_after_hours', 'previous_close', 'today opened', 'price range',
#        '52 week range', 'volume', 'average volume', 'market cap',
#        'beta (3Y Monthly)', 'PE Ratio', 'EPS', 'earnings date',
#        'Dividend Yield', '1Y target est'],
#       dtype='object')

# %%
# Print to see what is the type of your data set

print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# get the number of rows and columns

print(df.shape)
# Out:
# (67905, 19)

# %%
# Use groupby() and find the mean of price at close for each company

df.groupby('company_name')[['price_at_close','previous_close']].mean()
# Out:
#                                       price_at_close  previous_close
# company_name
# A - Agilent Technologies, Inc.             79.074615       79.194231
# AAL -                                      16.040000       18.530000
# AAL - American Airlines Group Inc.         20.505844       20.616753
# AAP -                                     126.920000      132.900000
# AAP - Advance Auto Parts, Inc.            127.387532      127.583247
# ...                                              ...             ...
# ZS -                                       52.693333       52.500000
# ZS - Zscaler, Inc.                         58.650500       58.749250
# ZTS - Zoetis Inc.                         128.024889      128.008111
# ZYNE -                                      4.163333        4.190000
# ZYNE - Zynerba Pharmaceuticals, Inc.        4.222143        4.261667
#
# [1486 rows x 2 columns]

# %%
df.groupby(df.date.dt.year)['price_at_close'].mean()
# Out:
# date
# 2019    207.241430
# 2020    480.823163
# Name: price_at_close, dtype: float64

# %%
# Use groupby() and find the mean of price at close, average volume, and PE Ratio for each company

multi_group_var = df.groupby(['company_name'])[['price_at_close', 'average volume','PE Ratio']].mean()

multi_group_var
# Out:
#                                       price_at_close  average volume  \
# company_name
# A - Agilent Technologies, Inc.             79.074615    2.027641e+06
# AAL -                                      16.040000             NaN
# AAL - American Airlines Group Inc.         20.505844    1.770994e+07
# AAP -                                     126.920000             NaN
# AAP - Advance Auto Parts, Inc.            127.387532    1.082102e+06
# ...                                              ...             ...
# ZS -                                       52.693333             NaN
# ZS - Zscaler, Inc.                         58.650500    2.560452e+06
# ZTS - Zoetis Inc.                         128.024889    2.301276e+06
# ZYNE -                                      4.163333             NaN
# ZYNE - Zynerba Pharmaceuticals, Inc.        4.222143    5.825955e+05
#
#                                        PE Ratio
# company_name
# A - Agilent Technologies, Inc.        28.374615
# ...
